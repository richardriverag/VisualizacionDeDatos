# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; text-align:center;">2025-2 · Máster universitario en Ciencia de datos (Data science)</p>
# <p style="margin: 0; text-align:center; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# <hr>
# <p style="margin: 0; text-align:center;">Asignatura: Visualización de Datos · PEC2</p>
# <p style="margin: 0; text-align:center;"><b>Estudiante: Richard Rivera</b></p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# ## Stacked Bar Graphs
# * Nombre: Stacked Bar, barras apiladas
# * Descipción: Es una variante de los gráficos de barras.
# * Se utilizan para mostrar cómo una categoría más grande se divide en categorías más pequeñas y cuál es la relación de cada parte sobre la cantidad total.
# * Tipos:
#   * Simple
#   * 100%
# <br>
# <img src="images/grafico_de_barras_apiladas.svg" alt="Texto" width="352" height="403">

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample Data
data = {
    'Category': ['A', 'B', 'C', 'D'],
    'Value1': [10, 20, 15, 25],
    'Value2': [12, 18, 20, 10],
    'Value3': [8, 22, 10, 30]
}
df = pd.DataFrame(data).set_index('Category')

# Create the stacked bar graph
ax = df.plot(kind='bar', stacked=True, title='Stacked Bar Graph (Pandas)', rot=0)

# Add a legend and display the plot
ax.legend(title='Series')
plt.show()

# %% [markdown]
# Waffle Chart

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle

data = {"Cats": 50, "Dogs": 30, "Rabbits": 20}

fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    title={"label": "Pet Popularity", "loc": "center"},
    legend={"loc": "lower left", "bbox_to_anchor": (0, -0.4), "ncol": len(data)}
)

plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# Tile grid Map

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %%
states = pd.read_csv('data/us_tile_grid.xls')

# %%
fig, axs = plt.subplots(1, figsize=(12, 6), dpi=300)
plt.xlim(0, 12)
plt.ylim(0, 8)
plt.axis('off')
axs.set_aspect('equal')
for _, state in states.iterrows():
    box = patches.Rectangle((state.column,state.row),1,1,linewidth=1,edgecolor='white',facecolor='lightgrey')
    plt.text(state.column + 0.5, state.row + 0.5, state.code, horizontalalignment='center', verticalalignment='center', color='dimgrey')
    axs.add_patch(box)

plt.show()
